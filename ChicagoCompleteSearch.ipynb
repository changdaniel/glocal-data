# %%
import requests
import json
from pprint import pprint


api_key='MnCHPxDw_JZAp6s1UM6ROOxlnCg7C0PktsSthWfAqPoff5WbpWsyRkrc4SZK7r85Er3N9DbqpYiD_NGAnhGSkgvqmInoP4eNnGt_Da4sdbHkxKCkFG57ruamBGu-XHYx'
headers = {'Authorization': 'Bearer %s' % api_key}

params = {'location':'Chicago'}
url='https://api.yelp.com/v3/businesses/search'

# %%
params = {'location':'Chicago', 'limit' : 50, 'offset': 0, 'categories':'zoos'}
req = requests.get(url, params=params, headers=headers)

json.loads(req.text)
# Out:
# {'businesses': [{'alias': 'lincoln-park-zoo-chicago',
#    'categories': [{'alias': 'zoos', 'title': 'Zoos'}],
#    'coordinates': {'latitude': 41.9209148287011,
#     'longitude': -87.6336050034629},
#    'display_phone': '(312) 742-2000',
#    'distance': 4052.359295955179,
#    'id': 'RQmbLZvI7XyFQd2JgNDVig',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Y1syO4zq5eDyBHJOeTMdZw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '2001 N Clark St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['2001 N Clark St', 'Chicago, IL 60614'],
#     'state': 'IL',
#     'zip_code': '60614'},
#    'name': 'Lincoln Park Zoo',
#    'phone': '+13127422000',
#    'rating': 4.5,
#    'review_count': 1206,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/lincoln-park-zoo-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'brookfield-zoo-brookfield',
#    'categories': [{'alias': 'zoos', 'title': 'Zoos'}],
#    'coordinates': {'latitude': 41.83055, 'longitude': -87.83226},
#    'display_phone': '(708) 688-8000',
#    'distance': 15445.923020801552,
#    'id': 'ZboeT_8JZUDPN2vr6L0itw',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wcyNI57_LfUWCXP2yL_RKg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '3300 Golf Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Brookfield',
#     'country': 'US',
#     'display_address': ['3300 Golf Rd', 'Brookfield, IL 60513'],
#     'state': 'IL',
#     'zip_code': '60513'},
#    'name': 'Brookfield Zoo',
#    'phone': '+17086888000',
#    'rating': 4.0,
#    'review_count': 655,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/brookfield-zoo-brookfield?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'scales-and-tales-traveling-zoo-chicago',
#    'categories': [{'alias': 'zoos', 'title': 'Zoos'},
#     {'alias': 'eventplanning', 'title': 'Party & Event Planning'}],
#    'coordinates': {'latitude': 41.85902, 'longitude': -87.65358},
#    'display_phone': '(312) 719-9428',
#    'distance': 6243.864485194591,
#    'id': 'en_X257_3-Y6rL7hS9uaTQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ezxd2HybhhfBxDBdw9SdaQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['Chicago, IL 60608'],
#     'state': 'IL',
#     'zip_code': '60608'},
#    'name': 'Scales & Tales Traveling Zoo',
#    'phone': '+13127199428',
#    'rating': 4.5,
#    'review_count': 11,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/scales-and-tales-traveling-zoo-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'willowbrook-wildlife-center-glen-ellyn',
#    'categories': [{'alias': 'zoos', 'title': 'Zoos'}],
#    'coordinates': {'latitude': 41.84288, 'longitude': -88.06033},
#    'display_phone': '(630) 942-6200',
#    'distance': 32529.819293351447,
#    'id': '9dSzFbsWrt0xxV1dAYLKmA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/n9q5ThJc_grM64fTEnW94w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '525 S Park Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Glen Ellyn',
#     'country': 'US',
#     'display_address': ['525 S Park Blvd', 'Glen Ellyn, IL 60137'],
#     'state': 'IL',
#     'zip_code': '60137'},
#    'name': 'Willowbrook Wildlife Center',
#    'phone': '+16309426200',
#    'rating': 4.5,
#    'review_count': 47,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/willowbrook-wildlife-center-glen-ellyn?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'jgs-reptile-road-show-des-plaines',
#    'categories': [{'alias': 'eventplanning',
#      'title': 'Party & Event Planning'},
#     {'alias': 'zoos', 'title': 'Zoos'},
#     {'alias': 'museums', 'title': 'Museums'}],
#    'coordinates': {'latitude': 42.046973, 'longitude': -87.890788},
#    'display_phone': '(847) 341-6624',
#    'distance': 23637.997509007553,
#    'id': 'jee5Z3j5OjtP4E4dXz9fUg',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SzF4XgQebiiDmrYwNyTiUw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'Des Plaines',
#     'country': 'US',
#     'display_address': ['Des Plaines, IL 60016'],
#     'state': 'IL',
#     'zip_code': '60016'},
#    'name': "JG's Reptile Road Show",
#    'phone': '+18473416624',
#    'rating': 5.0,
#    'review_count': 5,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/jgs-reptile-road-show-des-plaines?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'brookfield-zoo-run-run-brookfield',
#    'categories': [{'alias': 'zoos', 'title': 'Zoos'}],
#    'coordinates': {'latitude': 41.83124, 'longitude': -87.832935},
#    'display_phone': '(708) 688-8000',
#    'distance': 15252.913317028144,
#    'id': 'f2Yw5dJwvmzS-ERZExs__g',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rRteFkgMlbU6ohuvXeiUBw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '3300 Golf Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Brookfield',
#     'country': 'US',
#     'display_address': ['3300 Golf Rd', 'Brookfield, IL 60513'],
#     'state': 'IL',
#     'zip_code': '60513'},
#    'name': 'Brookfield Zoo Run Run',
#    'phone': '+17086888000',
#    'rating': 4.5,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/brookfield-zoo-run-run-brookfield?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'}],
#  'region': {'center': {'latitude': 41.90515925618311,
#    'longitude': -87.67776489257812}},
#  'total': 6}
