# %%
import requests
import json


api_key='MnCHPxDw_JZAp6s1UM6ROOxlnCg7C0PktsSthWfAqPoff5WbpWsyRkrc4SZK7r85Er3N9DbqpYiD_NGAnhGSkgvqmInoP4eNnGt_Da4sdbHkxKCkFG57ruamBGu-XHYx'
headers = {'Authorization': 'Bearer %s' % api_key}

params = {'location':'Evanston', 'limit' : 10, 'offset': 0}

# %%
url='https://api.yelp.com/v3/businesses/search'

req = requests.get(url, params=params, headers=headers)

# %%
# Making a get request to the API

# proceed only if the status code is 200
# print('The status code is {}'.format(req.status_code))

biginfolist = [];

for loopIndex in range(0,1600):

    params = {'location':'Evanston', 'limit' : 1, 'offset': (1 * loopIndex)}
    req = requests.get(url, params=params, headers=headers)
    infodict = json.loads(req.text)
    infolist = infodict.get('businesses')
    
    if infolist is None:
        continue
    else:
        biginfolist = biginfolist + infolist

# %%
print(len(biginfolist))
# Out:
# 999

# %%
for x in biginfolist:
    
#     if x.get('location').get('address1') is None:
#         continue
#     print(x.get('name') + "    " + x.get('location').get('address1'))
    for y in x.get('categories'):
        
        
        #print(y)
        if y.get('alias') == 'religiousorgs' :
            print(y)

# %%
params = {'location':'Evanston', 'limit' : 50, 'offset': 0, 'categories':'religiousorgs'}
req = requests.get(url, params=params, headers=headers)

json.loads(req.text)
# Out:
# {'businesses': [{'alias': 'bahai-house-of-worship-wilmette',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.0744270284347,
#     'longitude': -87.684292541709},
#    'display_phone': '(847) 853-2300',
#    'distance': 3118.6795616070385,
#    'id': '0KupoeNMfiyyaw9PX6KHqw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MJXZ_Qr43DtCchwSAzRIOQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '100 Linden Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Wilmette',
#     'country': 'US',
#     'display_address': ['100 Linden Ave', 'Wilmette, IL 60091'],
#     'state': 'IL',
#     'zip_code': '60091'},
#    'name': "Baha'i House of Worship",
#    'phone': '+18478532300',
#    'rating': 5.0,
#    'review_count': 146,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/bahai-house-of-worship-wilmette?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'vineyard-christian-church-of-evanston-evanston',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.0192849, 'longitude': -87.7084268},
#    'display_phone': '(847) 328-4533',
#    'distance': 3333.2595930761186,
#    'id': 'MUOjkbJoLg_U3Dse1fi1Lw',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SYdMSamkt_8ytradOWInEQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '2495 W Howard St',
#     'address2': None,
#     'address3': None,
#     'city': 'Evanston',
#     'country': 'US',
#     'display_address': ['2495 W Howard St', 'Evanston, IL 60202'],
#     'state': 'IL',
#     'zip_code': '60202'},
#    'name': 'Vineyard Christian Church of Evanston',
#    'phone': '+18473284533',
#    'rating': 5.0,
#    'review_count': 4,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/vineyard-christian-church-of-evanston-evanston?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-marys-church-evanston',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.0440051, 'longitude': -87.6853302},
#    'display_phone': '(847) 864-0333',
#    'distance': 905.5911251518776,
#    'id': 'j6eTr08rrhaHVlY9VbYYgg',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/J3eQZbSHX1E4wlGoHYk0CA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1012 Lake St',
#     'address2': '',
#     'address3': '',
#     'city': 'Evanston',
#     'country': 'US',
#     'display_address': ['1012 Lake St', 'Evanston, IL 60201'],
#     'state': 'IL',
#     'zip_code': '60201'},
#    'name': "St Mary's Church",
#    'phone': '+18478640333',
#    'rating': 5.0,
#    'review_count': 3,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-marys-church-evanston?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'iskcon-chicago-chicago',
#    'categories': [{'alias': 'hindu_temples', 'title': 'Hindu Temples'}],
#    'coordinates': {'latitude': 42.0091349, 'longitude': -87.6728319},
#    'display_phone': '(773) 973-0900',
#    'distance': 4673.414165857554,
#    'id': 'sTP3rZlGhvUEZyE2ACjNlQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M8fjacju2lQA6Fk_B78hhA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1716 W Lunt',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1716 W Lunt', 'Chicago, IL 60626'],
#     'state': 'IL',
#     'zip_code': '60626'},
#    'name': 'ISKCON Chicago',
#    'phone': '+17739730900',
#    'rating': 5.0,
#    'review_count': 14,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/iskcon-chicago-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'alice-millar-chapel-evanston',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.0506566178539,
#     'longitude': -87.6764656208218},
#    'display_phone': '',
#    'distance': 1641.8250930015122,
#    'id': 'Ub3TPYItBeCPLnwdDJYbAQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r3PK287l69YBh4DCo4Kh5Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1870 Sheridan Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Evanston',
#     'country': 'US',
#     'display_address': ['1870 Sheridan Rd', 'Evanston, IL 60208'],
#     'state': 'IL',
#     'zip_code': '60208'},
#    'name': 'Alice Millar Chapel',
#    'phone': '',
#    'rating': 4.5,
#    'review_count': 3,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/alice-millar-chapel-evanston?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-lukes-episcopal-church-evanston-2',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.0354339981, 'longitude': -87.677805480957},
#    'display_phone': '(847) 475-3630',
#    'distance': 2030.701133614356,
#    'id': 'mDSB-P-iXVbNsoXeZq4CqQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4jqW8s-lBiy1KHx3xEdcxQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '939 Hinman Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Evanston',
#     'country': 'US',
#     'display_address': ['939 Hinman Ave', 'Evanston, IL 60202'],
#     'state': 'IL',
#     'zip_code': '60202'},
#    'name': "St. Luke's Episcopal Church",
#    'phone': '+18474753630',
#    'rating': 4.5,
#    'review_count': 5,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-lukes-episcopal-church-evanston-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'second-baptist-church-evanston',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.049130050561, 'longitude': -87.68308347215},
#    'display_phone': '(847) 869-6955',
#    'distance': 1074.3018368202872,
#    'id': 'kHDi_P6Djv5_uk3BzoQrBA',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SpvAE6WxObfZKl8tHDGH-A/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1717 Benson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Evanston',
#     'country': 'US',
#     'display_address': ['1717 Benson Ave', 'Evanston, IL 60201'],
#     'state': 'IL',
#     'zip_code': '60201'},
#    'name': 'Second Baptist Church',
#    'phone': '+18478696955',
#    'rating': 4.0,
#    'review_count': 5,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/second-baptist-church-evanston?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'episcopal-church-of-the-atonement-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9867706298828,
#     'longitude': -87.6563186645508},
#    'display_phone': '(773) 271-2727',
#    'distance': 7529.792084672536,
#    'id': 'O2Ms39RiIgTEPuGynNjdRA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QNNrXDJmxr48F0DKVawIMg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '5749 N Kenmore Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['5749 N Kenmore Ave', 'Chicago, IL 60660'],
#     'state': 'IL',
#     'zip_code': '60660'},
#    'name': 'Episcopal Church of the Atonement',
#    'phone': '+17732712727',
#    'rating': 5.0,
#    'review_count': 10,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/episcopal-church-of-the-atonement-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'queen-of-all-saints-basilica-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9951956, 'longitude': -87.7440773},
#    'display_phone': '(773) 736-6060',
#    'distance': 7171.5582589232745,
#    'id': 'Q-T4Qb2dRQ2iDbPSXcTcjg',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eTFhQ-PnDopwBCDmNyG_zA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '6280 N Sauganash Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['6280 N Sauganash Ave', 'Chicago, IL 60646'],
#     'state': 'IL',
#     'zip_code': '60646'},
#    'name': 'Queen Of All Saints Basilica',
#    'phone': '+17737366060',
#    'rating': 5.0,
#    'review_count': 10,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/queen-of-all-saints-basilica-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'unitarian-church-of-evanston-evanston',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.04227, 'longitude': -87.68905},
#    'display_phone': '(847) 864-1330',
#    'distance': 836.99414422725,
#    'id': 'PcXaSvYmLgjDb1VCAx0jPQ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DUyRwkGyMC9ZldkgIn8Gdg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1330 Ridge Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Evanston',
#     'country': 'US',
#     'display_address': ['1330 Ridge Ave', 'Evanston, IL 60201'],
#     'state': 'IL',
#     'zip_code': '60201'},
#    'name': 'Unitarian Church of Evanston',
#    'phone': '+18478641330',
#    'rating': 3.0,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/unitarian-church-of-evanston-evanston?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'urban-village-church-chicago-9',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9815029, 'longitude': -87.659547},
#    'display_phone': '(312) 268-5300',
#    'distance': 7957.094483134225,
#    'id': 'FHeih_qb1BEy394X8Ize5Q',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/l6P11Qmdwek3ISrM0LDLZw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '5451 N Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['5451 N Broadway', 'Chicago, IL 60640'],
#     'state': 'IL',
#     'zip_code': '60640'},
#    'name': 'Urban Village Church',
#    'phone': '+13122685300',
#    'rating': 4.5,
#    'review_count': 17,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/urban-village-church-chicago-9?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-gertrudes-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9946211, 'longitude': -87.6659372},
#    'display_phone': '(773) 764-3621',
#    'distance': 6405.993695662998,
#    'id': 'fzJJ4ppO0FRg-4sTcxuZIA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3j5y1FiuqJ0LmD0sc0UnYQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1420 W Granville Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1420 W Granville Ave', 'Chicago, IL 60660'],
#     'state': 'IL',
#     'zip_code': '60660'},
#    'name': 'St Gertrudes Church',
#    'phone': '+17737643621',
#    'rating': 4.5,
#    'review_count': 12,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-gertrudes-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'zen-buddhist-temple-of-chicago-evanston-2',
#    'categories': [{'alias': 'buddhist_temples', 'title': 'Buddhist Temples'},
#     {'alias': 'karate', 'title': 'Karate'},
#     {'alias': 'taichi', 'title': 'Tai Chi'}],
#    'coordinates': {'latitude': 42.0410551, 'longitude': -87.680836},
#    'display_phone': '(847) 272-2070',
#    'distance': 1430.1781444337196,
#    'id': '3nmIvD_Fv-881vnPuwt7kg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dtHn5SiAJz5x9PjfJDEtfA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '608 Dempster St',
#     'address2': '',
#     'address3': '',
#     'city': 'Evanston',
#     'country': 'US',
#     'display_address': ['608 Dempster St', 'Evanston, IL 60202'],
#     'state': 'IL',
#     'zip_code': '60202'},
#    'name': 'Zen Buddhist Temple of Chicago',
#    'phone': '+18472722070',
#    'rating': 3.5,
#    'review_count': 3,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/zen-buddhist-temple-of-chicago-evanston-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-haralambos-greek-orthodox-church-niles',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.01627, 'longitude': -87.79051},
#    'display_phone': '(847) 647-8880',
#    'distance': 8555.211581197653,
#    'id': 'WR26L1ckY1M5WIpT6nD2mw',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PpMHACXB0FtyPj9ACZ6phQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '7373 N Caldwell Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Niles',
#     'country': 'US',
#     'display_address': ['7373 N Caldwell Ave', 'Niles, IL 60714'],
#     'state': 'IL',
#     'zip_code': '60714'},
#    'name': 'St Haralambos Greek Orthodox Church',
#    'phone': '+18476478880',
#    'rating': 4.5,
#    'review_count': 13,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-haralambos-greek-orthodox-church-niles?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-marys-syro-malankara-catholic-church-evanston',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.039806, 'longitude': -87.6936316},
#    'display_phone': '',
#    'distance': 904.1917395052233,
#    'id': 'OkASz2CuTCqFlmaVI5YDKw',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7Ryq_fx-EwQwcQaOFx9s-w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1208 Ashland Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Evanston',
#     'country': 'US',
#     'display_address': ['1208 Ashland Ave', 'Evanston, IL 60202'],
#     'state': 'IL',
#     'zip_code': '60202'},
#    'name': "St. Mary's Syro-Malankara Catholic Church",
#    'phone': '',
#    'rating': 5.0,
#    'review_count': 1,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-marys-syro-malankara-catholic-church-evanston?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'faith-at-first-evanston',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.047253, 'longitude': -87.677803},
#    'display_phone': '(847) 864-6181',
#    'distance': 1501.4847693422266,
#    'id': 'ry2g9XzSN2BjFqidnEK-6A',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AIIDGdMoUKJUp2NoAb4IgA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '516 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'Evanston',
#     'country': 'US',
#     'display_address': ['516 Church St', 'Evanston, IL 60201'],
#     'state': 'IL',
#     'zip_code': '60201'},
#    'name': 'Faith At First',
#    'phone': '+18478646181',
#    'rating': 5.0,
#    'review_count': 1,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/faith-at-first-evanston?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'unity-church-in-chicago-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9954746216536,
#     'longitude': -87.6775798201561},
#    'display_phone': '(773) 973-0007',
#    'distance': 6028.169590326043,
#    'id': 'JPXICBPsWqgbEzZintZ7yg',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PGKFaxih_wy5vP0gGYv6hA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1925 W Thome Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1925 W Thome Ave', 'Chicago, IL 60660'],
#     'state': 'IL',
#     'zip_code': '60660'},
#    'name': 'Unity Church In Chicago',
#    'phone': '+17739730007',
#    'rating': 5.0,
#    'review_count': 7,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/unity-church-in-chicago-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'beth-emet-the-free-synagogue-evanston',
#    'categories': [{'alias': 'synagogues', 'title': 'Synagogues'}],
#    'coordinates': {'latitude': 42.0411351, 'longitude': -87.6894573},
#    'display_phone': '(847) 869-4230',
#    'distance': 961.7667925075573,
#    'id': 'S4HFth2uBx4h7NjhZ5wtxg',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '1224 Dempster St',
#     'address2': '',
#     'address3': '',
#     'city': 'Evanston',
#     'country': 'US',
#     'display_address': ['1224 Dempster St', 'Evanston, IL 60202'],
#     'state': 'IL',
#     'zip_code': '60202'},
#    'name': 'Beth Emet the Free Synagogue',
#    'phone': '+18478694230',
#    'rating': 3.5,
#    'review_count': 3,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/beth-emet-the-free-synagogue-evanston?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'bahai-faith-evanston',
#    'categories': [{'alias': 'religiousorgs',
#      'title': 'Religious Organizations'}],
#    'coordinates': {'latitude': 42.0643649, 'longitude': -87.6885284},
#    'display_phone': '(847) 869-9039',
#    'distance': 1965.0472756638706,
#    'id': 'VdfwWBNpPSio1O3uUzx8iA',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '1233 Central St',
#     'address2': '',
#     'address3': '',
#     'city': 'Evanston',
#     'country': 'US',
#     'display_address': ['1233 Central St', 'Evanston, IL 60201'],
#     'state': 'IL',
#     'zip_code': '60201'},
#    'name': "Baha'i Faith",
#    'phone': '+18478699039',
#    'rating': 5.0,
#    'review_count': 1,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/bahai-faith-evanston?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'udumbara-zen-center-evanston',
#    'categories': [{'alias': 'buddhist_temples', 'title': 'Buddhist Temples'}],
#    'coordinates': {'latitude': 42.042342, 'longitude': -87.6889126},
#    'display_phone': '(847) 475-3264',
#    'distance': 836.99414422725,
#    'id': 'LrxX6zWD0FVqOWPzkXx4vg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Kc54YfACwuH3SKFUO2upRA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1330 Ridge Ave',
#     'address2': 'Room 2',
#     'address3': 'Unitarian Church of Evanston',
#     'city': 'Evanston',
#     'country': 'US',
#     'display_address': ['1330 Ridge Ave',
#      'Room 2',
#      'Unitarian Church of Evanston',
#      'Evanston, IL 60204'],
#     'state': 'IL',
#     'zip_code': '60204'},
#    'name': 'Udumbara Zen Center',
#    'phone': '+18474753264',
#    'rating': 3.5,
#    'review_count': 2,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/udumbara-zen-center-evanston?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'emanuel-congregation-chicago',
#    'categories': [{'alias': 'synagogues', 'title': 'Synagogues'}],
#    'coordinates': {'latitude': 41.990517, 'longitude': -87.654799},
#    'display_phone': '(773) 561-5173',
#    'distance': 7215.615622495388,
#    'id': 'uOyQy30N1DjF2tGJsF6gMw',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QwwQS3dQzaRPZB6DmZMgfg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '5959 N Sheridan Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['5959 N Sheridan Rd', 'Chicago, IL 60660'],
#     'state': 'IL',
#     'zip_code': '60660'},
#    'name': 'Emanuel Congregation',
#    'phone': '+17735615173',
#    'rating': 4.5,
#    'review_count': 11,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/emanuel-congregation-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-athanasius-roman-catholic-church-evanston',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.06261, 'longitude': -87.69465},
#    'display_phone': '(847) 328-1430',
#    'distance': 1638.06631377953,
#    'id': '2rCuMZXcs2vAKnhfFviu7g',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qxViDplVkQm5xdcFPj6nwg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1615 Lincoln St',
#     'address2': '',
#     'address3': '',
#     'city': 'Evanston',
#     'country': 'US',
#     'display_address': ['1615 Lincoln St', 'Evanston, IL 60201'],
#     'state': 'IL',
#     'zip_code': '60201'},
#    'name': 'St. Athanasius Roman Catholic Church',
#    'phone': '+18473281430',
#    'rating': 3.0,
#    'review_count': 2,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-athanasius-roman-catholic-church-evanston?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'first-evangelical-free-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9778259, 'longitude': -87.6695351},
#    'display_phone': '(773) 561-4175',
#    'distance': 8085.148982931308,
#    'id': '1pNLqdlaINPvcpxp6Nv1DQ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/N_OnQTJ9eiJajZ48WLtH-g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '5255 N Ashland Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['5255 N Ashland Ave', 'Chicago, IL 60640'],
#     'state': 'IL',
#     'zip_code': '60640'},
#    'name': 'First Evangelical Free Church',
#    'phone': '+17735614175',
#    'rating': 4.5,
#    'review_count': 9,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/first-evangelical-free-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'newstory-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9894964, 'longitude': -87.6584845},
#    'display_phone': '(773) 251-5587',
#    'distance': 7179.471190105412,
#    'id': 'Gx2ytqE8jPKqqJR53nxANQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fWMEfhdx0ALzh61lfbx90w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '5900 N Winthrop Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['5900 N Winthrop Ave', 'Chicago, IL 60660'],
#     'state': 'IL',
#     'zip_code': '60660'},
#    'name': 'NewStory Church',
#    'phone': '+17732515587',
#    'rating': 5.0,
#    'review_count': 5,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/newstory-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-marks-episcopal-church-evanston',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.045282343428,
#     'longitude': -87.6880728392868},
#    'display_phone': '(847) 864-4806',
#    'distance': 706.8516848323618,
#    'id': 'BRLGNaKz775WnPQXXs3aiQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PYiib-rr6hPYkZbWpfDjfg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1509 Ridge Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Evanston',
#     'country': 'US',
#     'display_address': ['1509 Ridge Ave', 'Evanston, IL 60201'],
#     'state': 'IL',
#     'zip_code': '60201'},
#    'name': "St. Mark's Episcopal Church",
#    'phone': '+18478644806',
#    'rating': 4.0,
#    'review_count': 1,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-marks-episcopal-church-evanston?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'trinity-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9901097, 'longitude': -87.6620773},
#    'display_phone': '(773) 789-7071',
#    'distance': 6994.014309670134,
#    'id': '7l5ENANvFEASgfFrRfI5NA',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DBZcnJm0yC4MsP0qPQaxqg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1244 W Thorndale Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1244 W Thorndale Ave', 'Chicago, IL 60660'],
#     'state': 'IL',
#     'zip_code': '60660'},
#    'name': 'Trinity Church',
#    'phone': '+17737897071',
#    'rating': 4.5,
#    'review_count': 8,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/trinity-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-lambert-church-skokie',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.02971, 'longitude': -87.73085},
#    'display_phone': '(847) 673-5090',
#    'distance': 3539.39410870773,
#    'id': '0u0SkMjPyE3iCEVfL0oXuQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yQMmrU7rq0FzOtfZQpxteg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '8148 Karlov Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Skokie',
#     'country': 'US',
#     'display_address': ['8148 Karlov Ave', 'Skokie, IL 60076'],
#     'state': 'IL',
#     'zip_code': '60076'},
#    'name': 'St Lambert Church',
#    'phone': '+18476735090',
#    'rating': 3.5,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-lambert-church-skokie?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'harvest-bible-chapel-niles',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.0154762268066,
#     'longitude': -87.7900924682617},
#    'display_phone': '(847) 398-7005',
#    'distance': 8563.217509783046,
#    'id': 'OtkMRMhoAAJc5RsKyvHpZw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZyDyA_e5yVq0zI76fNnzdA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '7333 N Caldwell',
#     'address2': '',
#     'address3': '',
#     'city': 'Niles',
#     'country': 'US',
#     'display_address': ['7333 N Caldwell', 'Niles, IL 60714'],
#     'state': 'IL',
#     'zip_code': '60714'},
#    'name': 'Harvest Bible Chapel',
#    'phone': '+18473987005',
#    'rating': 5.0,
#    'review_count': 5,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/harvest-bible-chapel-niles?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-pauls-church-by-the-lake-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.0118, 'longitude': -87.67056},
#    'display_phone': '(773) 764-6514',
#    'distance': 4518.609481247224,
#    'id': 'kYZ0fX-S5G8Kg1pJvSld6w',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/f6hMvFm5bP3TVcBEzFJSKQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '7100 N Ashland Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['7100 N Ashland Blvd', 'Chicago, IL 60626'],
#     'state': 'IL',
#     'zip_code': '60626'},
#    'name': "St Paul's Church By the Lake",
#    'phone': '+17737646514',
#    'rating': 5.0,
#    'review_count': 3,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-pauls-church-by-the-lake-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'jewish-reconstructionist-congregation-evanston',
#    'categories': [{'alias': 'synagogues', 'title': 'Synagogues'}],
#    'coordinates': {'latitude': 42.02305, 'longitude': -87.6993951},
#    'display_phone': '(847) 328-7678',
#    'distance': 2734.62771779451,
#    'id': 'gVR9YztJEfcA686d0Rep_g',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AwOw2zqqmBhEIl0W4m3xjw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '303 Dodge Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Evanston',
#     'country': 'US',
#     'display_address': ['303 Dodge Ave', 'Evanston, IL 60202'],
#     'state': 'IL',
#     'zip_code': '60202'},
#    'name': 'Jewish Reconstructionist Congregation',
#    'phone': '+18473287678',
#    'rating': 4.0,
#    'review_count': 1,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/jewish-reconstructionist-congregation-evanston?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'windy-city-community-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9919345, 'longitude': -87.7972836},
#    'display_phone': '(773) 631-9222',
#    'distance': 10382.093081797444,
#    'id': 'EqEF1NRGNrTk_6ozJvs-Wg',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Crj9OINv3Js4ZYGKM-2hhQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '6131 N Newark Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['6131 N Newark Ave', 'Chicago, IL 60631'],
#     'state': 'IL',
#     'zip_code': '60631'},
#    'name': 'Windy City Community Church',
#    'phone': '+17736319222',
#    'rating': 5.0,
#    'review_count': 5,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/windy-city-community-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'ebenezer-lutheran-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9762808, 'longitude': -87.6709104},
#    'display_phone': '(773) 561-8496',
#    'distance': 8174.175634100665,
#    'id': 'WG7JxilGnkN3CAkWHBQ2KA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m7_JnFULkEw671hjpTygBA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1650 W Foster Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1650 W Foster Ave', 'Chicago, IL 60640'],
#     'state': 'IL',
#     'zip_code': '60640'},
#    'name': 'Ebenezer Lutheran Church',
#    'phone': '+17735618496',
#    'rating': 4.5,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/ebenezer-lutheran-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-gregory-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9827711, 'longitude': -87.6720606},
#    'display_phone': '(773) 561-3546',
#    'distance': 7467.230576041068,
#    'id': 'fBkrUvGZl1d24IZU3eP3hg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hvdD85Q1hfy3q_c9OgDuVQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '5545 N Paulina St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['5545 N Paulina St', 'Chicago, IL 60640'],
#     'state': 'IL',
#     'zip_code': '60640'},
#    'name': 'St Gregory Church',
#    'phone': '+17735613546',
#    'rating': 4.5,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-gregory-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'first-presbyterian-church-of-wilmette-wilmette',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.0753488, 'longitude': -87.7008083},
#    'display_phone': '(847) 256-3010',
#    'distance': 3128.0592753587794,
#    'id': 'I1TVfvK7FL3m5pwGf4kX4Q',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '600 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Wilmette',
#     'country': 'US',
#     'display_address': ['600 9th St', 'Wilmette, IL 60091'],
#     'state': 'IL',
#     'zip_code': '60091'},
#    'name': 'First Presbyterian Church of Wilmette',
#    'phone': '+18472563010',
#    'rating': 4.5,
#    'review_count': 2,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/first-presbyterian-church-of-wilmette-wilmette?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'temple-judea-mizpah-skokie',
#    'categories': [{'alias': 'synagogues', 'title': 'Synagogues'}],
#    'coordinates': {'latitude': 42.037727355957,
#     'longitude': -87.7498245239258},
#    'display_phone': '(847) 676-1566',
#    'distance': 4637.475618671303,
#    'id': 'VLyDrjvU5_RAJW7O-v-VZw',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aa_tSb7s5VZAdhAR-wQdvw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '8610 Niles Center Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Skokie',
#     'country': 'US',
#     'display_address': ['8610 Niles Center Rd', 'Skokie, IL 60077'],
#     'state': 'IL',
#     'zip_code': '60077'},
#    'name': 'Temple Judea Mizpah',
#    'phone': '+18476761566',
#    'rating': 5.0,
#    'review_count': 3,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/temple-judea-mizpah-skokie?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'madonna-della-strada-chapel-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9995898366622,
#     'longitude': -87.6561701931853},
#    'display_phone': '(773) 508-8045',
#    'distance': 6283.53576352458,
#    'id': 'QOSocSeJE_lOqJoolaZ0pw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yV5ipsUnfwwzNXnI4INJKA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1032 W Sheridan Rd',
#     'address2': '',
#     'address3': 'Loyola University Chicago',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1032 W Sheridan Rd',
#      'Loyola University Chicago',
#      'Chicago, IL 60660'],
#     'state': 'IL',
#     'zip_code': '60660'},
#    'name': 'Madonna della Strada Chapel',
#    'phone': '+17735088045',
#    'rating': 4.0,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/madonna-della-strada-chapel-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'ethical-humanist-society-skokie',
#    'categories': [{'alias': 'religiousorgs',
#      'title': 'Religious Organizations'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'coordinates': {'latitude': 42.0187187194824,
#     'longitude': -87.7486724853516},
#    'display_phone': '(847) 677-3334',
#    'distance': 5431.40304190469,
#    'id': '5-dD8qd_bJelvO4BLaaVfw',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8drQfcvmcBjebL3gES-A_Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '7574 Lincoln Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Skokie',
#     'country': 'US',
#     'display_address': ['7574 Lincoln Ave', 'Skokie, IL 60077'],
#     'state': 'IL',
#     'zip_code': '60077'},
#    'name': 'Ethical Humanist Society',
#    'phone': '+18476773334',
#    'rating': 4.0,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/ethical-humanist-society-skokie?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-ita-catholic-church-chicago-2',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9819255, 'longitude': -87.6602014},
#    'display_phone': '(773) 561-5343',
#    'distance': 7879.855515134471,
#    'id': 'vUr8-gwv6jrBTg-OF98cKQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-UI3HdWoTNC2J-O0uDyzBQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '5500 N Broadway St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['5500 N Broadway St', 'Chicago, IL 60640'],
#     'state': 'IL',
#     'zip_code': '60640'},
#    'name': 'St Ita Catholic Church',
#    'phone': '+17735615343',
#    'rating': 4.0,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-ita-catholic-church-chicago-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-ignatius-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.0019502, 'longitude': -87.6654851},
#    'display_phone': '(773) 764-5936',
#    'distance': 5730.976740971996,
#    'id': 's5q0f_0XfiJr1OHEvMl0AQ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LKsQMk-M21axdpJ5Jo2wFA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '6559 N Glenwood Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['6559 N Glenwood Ave', 'Chicago, IL 60626'],
#     'state': 'IL',
#     'zip_code': '60626'},
#    'name': 'St Ignatius Church',
#    'phone': '+17737645936',
#    'rating': 5.0,
#    'review_count': 3,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-ignatius-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'community-church-of-wilmette-wilmette',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.080566, 'longitude': -87.704101},
#    'display_phone': '(847) 251-4370',
#    'distance': 3724.2713651768036,
#    'id': 'zey_tKxxuQcbaJ3xOmuD8A',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JNCubBW2SrpQMyhv6phNaw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1020 Forest Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Wilmette',
#     'country': 'US',
#     'display_address': ['1020 Forest Ave', 'Wilmette, IL 60091'],
#     'state': 'IL',
#     'zip_code': '60091'},
#    'name': 'Community Church of Wilmette',
#    'phone': '+18472514370',
#    'rating': 4.5,
#    'review_count': 3,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/community-church-of-wilmette-wilmette?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-francis-xavier-catholic-church-wilmette',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.0742027, 'longitude': -87.7008536},
#    'display_phone': '(847) 256-4250',
#    'distance': 2957.65221697084,
#    'id': 'Jj02tZntQ77CfJUxCkYbjQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5QTwrIJ6VSreleGkMPdLww/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '524 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Wilmette',
#     'country': 'US',
#     'display_address': ['524 9th St', 'Wilmette, IL 60091'],
#     'state': 'IL',
#     'zip_code': '60091'},
#    'name': 'St Francis Xavier Catholic Church',
#    'phone': '+18472564250',
#    'rating': 3.5,
#    'review_count': 3,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-francis-xavier-catholic-church-wilmette?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-peters-cath-church-skokie',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.0292053222656,
#     'longitude': -87.7541198730469},
#    'display_phone': '(847) 673-1492',
#    'distance': 5304.215257499631,
#    'id': 'Gz6DkGGNJ_loMENgY6CJPw',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MQFws4CkY5D0J2YM7smPnw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '8116 Niles Center Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Skokie',
#     'country': 'US',
#     'display_address': ['8116 Niles Center Rd', 'Skokie, IL 60077'],
#     'state': 'IL',
#     'zip_code': '60077'},
#    'name': "St Peter's Cath Church",
#    'phone': '+18476731492',
#    'rating': 4.0,
#    'review_count': 5,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-peters-cath-church-skokie?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'lake-street-church-of-evanston-evanston',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.0441961, 'longitude': -87.680741},
#    'display_phone': '(847) 864-2181',
#    'distance': 1297.6555354737768,
#    'id': 'PP9QOQYnudXwLPpp-Fd17Q',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '607 Lake St',
#     'address2': '',
#     'address3': '',
#     'city': 'Evanston',
#     'country': 'US',
#     'display_address': ['607 Lake St', 'Evanston, IL 60201'],
#     'state': 'IL',
#     'zip_code': '60201'},
#    'name': 'Lake Street Church of Evanston',
#    'phone': '+18478642181',
#    'rating': 4.5,
#    'review_count': 2,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/lake-street-church-of-evanston-evanston?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'kenilworth-union-church-kenilworth',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.0906060206, 'longitude': -87.7119555479},
#    'display_phone': '(847) 251-4272',
#    'distance': 4944.718029078055,
#    'id': 'aiciaN--Ai5_wkOZtykWig',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pB6QOdRvXivAmz7Y3srT-w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '211 Kenilworth Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Kenilworth',
#     'country': 'US',
#     'display_address': ['211 Kenilworth Ave', 'Kenilworth, IL 60043'],
#     'state': 'IL',
#     'zip_code': '60043'},
#    'name': 'Kenilworth Union Church',
#    'phone': '+18472514272',
#    'rating': 5.0,
#    'review_count': 2,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/kenilworth-union-church-kenilworth?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'beth-hillel-congregation-wilmette',
#    'categories': [{'alias': 'synagogues', 'title': 'Synagogues'}],
#    'coordinates': {'latitude': 42.0695686, 'longitude': -87.7554779},
#    'display_phone': '(847) 256-1213',
#    'distance': 5498.1527282225225,
#    'id': 'f1FAZAushtDqPp7HHnf--w',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '3220 Big Tree Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'Wilmette',
#     'country': 'US',
#     'display_address': ['3220 Big Tree Ln', 'Wilmette, IL 60091'],
#     'state': 'IL',
#     'zip_code': '60091'},
#    'name': 'Beth Hillel Congregation',
#    'phone': '+18472561213',
#    'rating': 4.0,
#    'review_count': 5,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/beth-hillel-congregation-wilmette?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'evanston-baptist-church-evanston-2',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.0485658, 'longitude': -87.6985931},
#    'display_phone': '',
#    'distance': 235.44467689569166,
#    'id': 'TIsRx-xFvVdyw8dZCETQsQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/k_PZK9P3qBirTtfKH8DJfA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1823 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'Evanston',
#     'country': 'US',
#     'display_address': ['1823 Church St', 'Evanston, IL 60201'],
#     'state': 'IL',
#     'zip_code': '60201'},
#    'name': 'Evanston Baptist Church',
#    'phone': '',
#    'rating': 5.0,
#    'review_count': 1,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/evanston-baptist-church-evanston-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'trinity-united-methodist-church-wilmette',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.0792083740234,
#     'longitude': -87.7041473388672},
#    'display_phone': '(847) 251-7333',
#    'distance': 3569.6361569579285,
#    'id': 'silPH_ZfDCQNNJBJs2xwJg',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MHwrB_dT4_BZvmVinxfEHg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1024 Lake Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Wilmette',
#     'country': 'US',
#     'display_address': ['1024 Lake Ave', 'Wilmette, IL 60091'],
#     'state': 'IL',
#     'zip_code': '60091'},
#    'name': 'Trinity United Methodist Church',
#    'phone': '+18472517333',
#    'rating': 5.0,
#    'review_count': 1,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/trinity-united-methodist-church-wilmette?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'gurdwara-sahib-of-chicago-chicago',
#    'categories': [{'alias': 'religiousorgs',
#      'title': 'Religious Organizations'}],
#    'coordinates': {'latitude': 41.9974784851074,
#     'longitude': -87.689094543457},
#    'display_phone': '(773) 274-3133',
#    'distance': 5616.156517715139,
#    'id': 'Y-tIw34vI8gd5CurYRsEqw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2zd9mw2WkI-0H6ciLyS9Zw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '2341 W Devon Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['2341 W Devon Ave', 'Chicago, IL 60659'],
#     'state': 'IL',
#     'zip_code': '60659'},
#    'name': 'Gurdwara Sahib of Chicago',
#    'phone': '+17732743133',
#    'rating': 5.0,
#    'review_count': 2,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/gurdwara-sahib-of-chicago-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-jeromes-church-chicago-2',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.0088651, 'longitude': -87.6726799},
#    'display_phone': '(773) 262-3170',
#    'distance': 4744.766831056545,
#    'id': 'fB-Gx5fv75f8bKJCEhXkQA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NCd0AohDi4RhAcku0hlC5g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1709 W Lunt Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1709 W Lunt Ave', 'Chicago, IL 60626'],
#     'state': 'IL',
#     'zip_code': '60626'},
#    'name': 'St Jeromes Church',
#    'phone': '+17732623170',
#    'rating': 3.5,
#    'review_count': 3,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-jeromes-church-chicago-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-nicholas-roman-catholic-church-evanston',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 42.0324668884277,
#     'longitude': -87.6870727539062},
#    'display_phone': '(847) 864-1185',
#    'distance': 1870.4784955421012,
#    'id': 'ZMG0zC-n4C_mcpbInA90GQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/apwrqNZYIFLgRoAxwV5fVA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '806 Ridge Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Evanston',
#     'country': 'US',
#     'display_address': ['806 Ridge Ave', 'Evanston, IL 60202'],
#     'state': 'IL',
#     'zip_code': '60202'},
#    'name': 'St Nicholas Roman Catholic Church',
#    'phone': '+18478641185',
#    'rating': 5.0,
#    'review_count': 1,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-nicholas-roman-catholic-church-evanston?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'}],
#  'region': {'center': {'latitude': 42.047751464985495,
#    'longitude': -87.69596099853516}},
#  'total': 117}
