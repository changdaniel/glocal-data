# %%
import requests
import json
from pprint import pprint


api_key='MnCHPxDw_JZAp6s1UM6ROOxlnCg7C0PktsSthWfAqPoff5WbpWsyRkrc4SZK7r85Er3N9DbqpYiD_NGAnhGSkgvqmInoP4eNnGt_Da4sdbHkxKCkFG57ruamBGu-XHYx'
headers = {'Authorization': 'Bearer %s' % api_key}

params = {'location':'Chicago','offset': 980}

# %%
url='https://api.yelp.com/v3/businesses/search'

req = requests.get(url, params=params, headers=headers)
json.loads(req.text)
# Out:
# {'businesses': [{'alias': 'paddy-longs-chicago-2',
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'irish', 'title': 'Irish'}],
#    'coordinates': {'latitude': 41.93287, 'longitude': -87.65504},
#    'display_phone': '(773) 290-6988',
#    'distance': 3594.448905931775,
#    'id': 'lFuxZf4-nCThJd8fV_EwBw',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IyU_Lpa6vBc726ad7hlkEA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1028 W Diversey Pkwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1028 W Diversey Pkwy', 'Chicago, IL 60614'],
#     'state': 'IL',
#     'zip_code': '60614'},
#    'name': "Paddy Long's",
#    'phone': '+17732906988',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 380,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/paddy-longs-chicago-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'yassa-african-restaurant-chicago-2',
#    'categories': [{'alias': 'senegalese', 'title': 'Senegalese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'coordinates': {'latitude': 41.830723756206,
#     'longitude': -87.6167381675416},
#    'display_phone': '(773) 488-5599',
#    'distance': 9697.53433876867,
#    'id': 'CjAKxQ0okWHqtz0o4jxMFg',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_aFac2TpP_CZNN9F8nPbAA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '3511 S King Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['3511 S King Dr', 'Chicago, IL 60653'],
#     'state': 'IL',
#     'zip_code': '60653'},
#    'name': 'Yassa African Restaurant',
#    'phone': '+17734885599',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 247,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/yassa-african-restaurant-chicago-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'shake-shack-chicago-2',
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 41.881664, 'longitude': -87.624969},
#    'display_phone': '(312) 646-6005',
#    'distance': 5092.791783587564,
#    'id': 'i0DvXKkPTHQC4HOnp8Z2Zg',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vgnDTwxoxO2Dk3Kv477rwQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '12 S Michigan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['12 S Michigan Ave', 'Chicago, IL 60603'],
#     'state': 'IL',
#     'zip_code': '60603'},
#    'name': 'Shake Shack',
#    'phone': '+13126466005',
#    'price': '$$',
#    'rating': 3.5,
#    'review_count': 552,
#    'transactions': ['delivery'],
#    'url': 'https://www.yelp.com/biz/shake-shack-chicago-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'forever-yogurt-chicago-8',
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'coordinates': {'latitude': 41.9106025, 'longitude': -87.67625083},
#    'display_phone': '(773) 772-4770',
#    'distance': 621.4485839034261,
#    'id': 'r48hk3DQNfAP4hyuau0cUQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QbcfsnSRDc8z_nm1ZRhaFA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1924 W North Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1924 W North Ave', 'Chicago, IL 60614'],
#     'state': 'IL',
#     'zip_code': '60614'},
#    'name': 'Forever Yogurt',
#    'phone': '+17737724770',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 288,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/forever-yogurt-chicago-8?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'red-hot-ranch-chicago-3',
#    'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'coordinates': {'latitude': 41.9375348836184,
#     'longitude': -87.6685266941786},
#    'display_phone': '(773) 661-9377',
#    'distance': 3680.2462313122946,
#    'id': 'orZRAjCMGQrNsoshGAwDkA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7hvi8yt3rRZhdwoaDUquNQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '3057 N Ashland Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['3057 N Ashland Ave', 'Chicago, IL 60657'],
#     'state': 'IL',
#     'zip_code': '60657'},
#    'name': 'Red Hot Ranch',
#    'phone': '+17736619377',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 221,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/red-hot-ranch-chicago-3?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'bellemore-chicago-2',
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'coordinates': {'latitude': 41.8847, 'longitude': -87.6423},
#    'display_phone': '(312) 667-0104',
#    'distance': 3709.4879934516507,
#    'id': 'RqUPrDTsGTuCzwQylbAEtg',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4oRJS2wbkaURWeW8oCdtBQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '564 W Randolph St',
#     'address2': None,
#     'address3': None,
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['564 W Randolph St', 'Chicago, IL 60661'],
#     'state': 'IL',
#     'zip_code': '60661'},
#    'name': 'Bellemore',
#    'phone': '+13126670104',
#    'price': '$$$$',
#    'rating': 4.0,
#    'review_count': 191,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/bellemore-chicago-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'protein-bar-chicago-4',
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'coordinates': {'latitude': 41.8889455786121,
#     'longitude': -87.6312258839607},
#    'display_phone': '(312) 527-0450',
#    'distance': 4252.951216212068,
#    'id': 'ax-3aOMpoJD9jaoU75g96A',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nx54Yq_ZVv2ndccT3xL0Dg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '352 N Clark',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['352 N Clark', 'Chicago, IL 60654'],
#     'state': 'IL',
#     'zip_code': '60654'},
#    'name': 'Protein Bar',
#    'phone': '+13125270450',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 270,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/protein-bar-chicago-4?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'driehaus-museum-chicago',
#    'categories': [{'alias': 'museums', 'title': 'Museums'}],
#    'coordinates': {'latitude': 41.8939343632448,
#     'longitude': -87.6274770509009},
#    'display_phone': '(312) 482-8933',
#    'distance': 4345.155967632669,
#    'id': '1Sz1C_jyrjx_f7I7jyyOpw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jlc6uoV03C_3GO3WQwWpxw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '40 E Erie St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['40 E Erie St', 'Chicago, IL 60611'],
#     'state': 'IL',
#     'zip_code': '60611'},
#    'name': 'Driehaus Museum',
#    'phone': '+13124828933',
#    'rating': 4.5,
#    'review_count': 101,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/driehaus-museum-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'heaven-on-seven-wabash-chicago',
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'southern', 'title': 'Southern'}],
#    'coordinates': {'latitude': 41.88347, 'longitude': -87.62575},
#    'display_phone': '(312) 263-6443',
#    'distance': 4923.333002448708,
#    'id': 'KdTYm6S6PyIIEfYHHONZkw',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RFF1mm3z1ZdMuEcjhmDKzg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '111 N Wabash Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['111 N Wabash Ave', 'Chicago, IL 60602'],
#     'state': 'IL',
#     'zip_code': '60602'},
#    'name': 'Heaven on Seven Wabash',
#    'phone': '+13122636443',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 407,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/heaven-on-seven-wabash-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'hamburger-marys-chicago-2',
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'coordinates': {'latitude': 41.97997, 'longitude': -87.66851},
#    'display_phone': '(773) 784-6969',
#    'distance': 8352.899537010202,
#    'id': 'Rs2n1VDDD6pkQqexBAJJ0w',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c02FoFy0A1v13uCVVkaWsQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '5400 N Clark St',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['5400 N Clark St', 'Chicago, IL 60640'],
#     'state': 'IL',
#     'zip_code': '60640'},
#    'name': "Hamburger Mary's",
#    'phone': '+17737846969',
#    'price': '$$',
#    'rating': 3.5,
#    'review_count': 958,
#    'transactions': ['restaurant_reservation'],
#    'url': 'https://www.yelp.com/biz/hamburger-marys-chicago-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'paulie-gees-logan-square-chicago',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'coordinates': {'latitude': 41.92589, 'longitude': -87.70168},
#    'display_phone': '(773) 360-1072',
#    'distance': 3044.714376506853,
#    'id': 'Xh5vGcoKk-SaBw7GUZDFxg',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Pk1Gq00_y7i4qSjqNcITeQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '2451 N Milwaukee Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['2451 N Milwaukee Ave', 'Chicago, IL 60647'],
#     'state': 'IL',
#     'zip_code': '60647'},
#    'name': "Paulie Gee's Logan Square",
#    'phone': '+17733601072',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 299,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/paulie-gees-logan-square-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'mins-noodle-house-chicago-37',
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'szechuan', 'title': 'Szechuan'}],
#    'coordinates': {'latitude': 41.8353899, 'longitude': -87.64586},
#    'display_phone': '(312) 465-2999',
#    'distance': 8196.285878376715,
#    'id': '0F80pfvLYzKdHhSakhbYAg',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pe0if1Wy-e1Sgr26fKWtPQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '3235 S Halsted St',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['3235 S Halsted St', 'Chicago, IL 60608'],
#     'state': 'IL',
#     'zip_code': '60608'},
#    'name': "Min's Noodle House",
#    'phone': '+13124652999',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 237,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/mins-noodle-house-chicago-37?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'twisted-tapas-chicago-2',
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'coordinates': {'latitude': 42.0056775, 'longitude': -87.6600462},
#    'display_phone': '(773) 856-3486',
#    'distance': 11289.788849834104,
#    'id': '7Br2Xp5XBj5wYEoXWy6fRA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-X3rEOUhpwsLDNpCKHkKnQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1146 W Pratt Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1146 W Pratt Blvd', 'Chicago, IL 60626'],
#     'state': 'IL',
#     'zip_code': '60626'},
#    'name': 'Twisted Tapas',
#    'phone': '+17738563486',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 309,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/twisted-tapas-chicago-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'exchequer-restaurant-and-pub-chicago',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 41.8787384660152,
#     'longitude': -87.6263198788816},
#    'display_phone': '(312) 939-5633',
#    'distance': 5173.412080066813,
#    'id': 'q9AUsrYTakTMIHJkKA_EIQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IWNK1yzGmLWmT_LdkH3u4g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '226 S Wabash Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['226 S Wabash Ave', 'Chicago, IL 60604'],
#     'state': 'IL',
#     'zip_code': '60604'},
#    'name': 'Exchequer Restaurant & Pub',
#    'phone': '+13129395633',
#    'price': '$$',
#    'rating': 3.5,
#    'review_count': 537,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/exchequer-restaurant-and-pub-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'kāl-ish-chicago',
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'coordinates': {'latitude': 41.9651912, 'longitude': -87.6629087},
#    'display_phone': '(773) 293-7768',
#    'distance': 6785.009354117159,
#    'id': 'p9_aj36ycQx-oqx4puFzwg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p9pri0ijgAXUkSAura--sg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1313 W Wilson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1313 W Wilson Ave', 'Chicago, IL 60640'],
#     'state': 'IL',
#     'zip_code': '60640'},
#    'name': "Kāl'ish",
#    'phone': '+17732937768',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 175,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/k%C4%81l-ish-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'nandos-peri-peri-chicago-18',
#    'categories': [{'alias': 'portuguese', 'title': 'Portuguese'},
#     {'alias': 'southafrican', 'title': 'South African'},
#     {'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#    'coordinates': {'latitude': 41.8812209, 'longitude': -87.6263332},
#    'display_phone': '(312) 589-7432',
#    'distance': 4987.1335909190875,
#    'id': 'nlzCOQG-8oKBOGMMtbreTg',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BM0hah8CreN_PfUYKNoEvg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '22 S Wabash Ave',
#     'address2': 'Ste B1',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['22 S Wabash Ave', 'Ste B1', 'Chicago, IL 60603'],
#     'state': 'IL',
#     'zip_code': '60603'},
#    'name': "Nando's PERi-PERi",
#    'phone': '+13125897432',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 356,
#    'transactions': ['pickup'],
#    'url': 'https://www.yelp.com/biz/nandos-peri-peri-chicago-18?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'ryuu-asian-bbq-and-sushi-chicago',
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'coordinates': {'latitude': 41.9313684850931,
#     'longitude': -87.7113179862499},
#    'display_phone': '(773) 661-1919',
#    'distance': 4032.8890764123,
#    'id': 'pglLq_8c2grcKez_wX8WPw',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DKxsztJssrLyrU0e0QfK5w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '2766 N Milwaukee Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['2766 N Milwaukee Ave', 'Chicago, IL 60647'],
#     'state': 'IL',
#     'zip_code': '60647'},
#    'name': 'RYUU Asian BBQ & Sushi',
#    'phone': '+17736611919',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 179,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/ryuu-asian-bbq-and-sushi-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'baptiste-and-bottle-chicago',
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'coordinates': {'latitude': 41.893975, 'longitude': -87.6252358},
#    'display_phone': '(312) 667-6793',
#    'distance': 4521.90130871078,
#    'id': 'JfgS1O2N84LCnEnzUY8bSQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OF1sDjMH1GfrCRmGa2MACA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '101 E Erie St',
#     'address2': 'Fl 20',
#     'address3': None,
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['101 E Erie St', 'Fl 20', 'Chicago, IL 60611'],
#     'state': 'IL',
#     'zip_code': '60611'},
#    'name': 'Baptiste & Bottle',
#    'phone': '+13126676793',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 293,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/baptiste-and-bottle-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'nohea-cafe-chicago',
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'coordinates': {'latitude': 41.8817241, 'longitude': -87.6603567},
#    'display_phone': '(312) 600-9305',
#    'distance': 2977.7128484721,
#    'id': 'sQ-IPzNMgkDkF7BWb9cApw',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lpoj5fgBKEFz821UJXImIg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1312 W Madison St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1312 W Madison St', 'Chicago, IL 60607'],
#     'state': 'IL',
#     'zip_code': '60607'},
#    'name': 'Nohea Cafe',
#    'phone': '+13126009305',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 223,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/nohea-cafe-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'allende-restaurant-chicago',
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'coordinates': {'latitude': 41.9257122, 'longitude': -87.6493817},
#    'display_phone': '(773) 477-7114',
#    'distance': 3277.5583895457003,
#    'id': '1BLEz3cD4DHcAxlTu_Yb4g',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/u5Xem4gFSycWIFByTgeSvw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '2408 N Lincoln Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['2408 N Lincoln Ave', 'Chicago, IL 60614'],
#     'state': 'IL',
#     'zip_code': '60614'},
#    'name': 'Allende Restaurant',
#    'phone': '+17734777114',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 355,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/allende-restaurant-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'}],
#  'region': {'center': {'latitude': 41.90515925618311,
#    'longitude': -87.67776489257812}},
#  'total': 8400}

# %%
# Making a get request to the API

# proceed only if the status code is 200
# print('The status code is {}'.format(req.status_code))

biginfolist = [];

for loopIndex in range(999):

    params = {'location':'Chicago', 'limit' : 1, 'offset': (1 * loopIndex)}
    req = requests.get(url, params=params, headers=headers)
    infodict = json.loads(req.text)
    infolist = infodict.get('businesses')
    
    if infolist is None:
        continue
    else:
        biginfolist = biginfolist + infolist

# %%
print(len(biginfolist))
# Out:
# 999

# %%
for x in biginfolist:
    
#     if x.get('location').get('address1') is None:
#         continue
#     print(x.get('name') + "    " + x.get('location').get('address1'))
    for y in x.get('categories'):
        
        
        #print(y)
        if y.get('alias') == 'religiousorgs' :
            pprint(x)

# %%
params = {'location':'Chicago', 'limit' : 50, 'offset': 0, 'categories':'religiousorgs'}
req = requests.get(url, params=params, headers=headers)

json.loads(req.text)
# Out:
# {'businesses': [{'alias': 'holy-name-cathedral-parish-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.8958267, 'longitude': -87.6280251},
#    'display_phone': '(312) 787-8040',
#    'distance': 4273.947045316862,
#    'id': '0jb1z7xpltdmWQ2i_8H5yg',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Xq4j-GqCaUcKzaGKzMKt0g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '735 N State St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['735 N State St', 'Chicago, IL 60611'],
#     'state': 'IL',
#     'zip_code': '60611'},
#    'name': 'Holy Name Cathedral Parish',
#    'phone': '+13127878040',
#    'rating': 4.5,
#    'review_count': 87,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/holy-name-cathedral-parish-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-mary-of-the-angels-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'},
#     {'alias': 'landmarks', 'title': 'Landmarks & Historical Buildings'}],
#    'coordinates': {'latitude': 41.91512, 'longitude': -87.67207},
#    'display_phone': '(773) 278-2644',
#    'distance': 1269.8104255210728,
#    'id': 'dftBRfw46hwn2huJVfHeMQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2QRUJ2BYhbmLKWDRLSSQAA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1850 N Hermitage Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1850 N Hermitage Ave', 'Chicago, IL 60622'],
#     'state': 'IL',
#     'zip_code': '60622'},
#    'name': 'St Mary of the Angels Church',
#    'phone': '+17732782644',
#    'rating': 4.5,
#    'review_count': 50,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-mary-of-the-angels-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-john-cantius-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'},
#     {'alias': 'landmarks', 'title': 'Landmarks & Historical Buildings'}],
#    'coordinates': {'latitude': 41.8966223, 'longitude': -87.6534298},
#    'display_phone': '(312) 243-7373',
#    'distance': 2204.774650942214,
#    'id': 'wcWkk4f4l7OQp_fn9zDzYg',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/h9eOPaw7EPde85UrOaM2yg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '825 N Carpenter St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['825 N Carpenter St', 'Chicago, IL 60642'],
#     'state': 'IL',
#     'zip_code': '60642'},
#    'name': 'St John Cantius Church',
#    'phone': '+13122437373',
#    'rating': 4.5,
#    'review_count': 33,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-john-cantius-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'old-st-patricks-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.8793945, 'longitude': -87.6442281},
#    'display_phone': '(312) 648-1021',
#    'distance': 3972.007835784068,
#    'id': 'P62YTe4qqji1SIeEBrHEXw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/awsipeXeP839EYp_ez2FvQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '700 W Adams St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['700 W Adams St', 'Chicago, IL 60661'],
#     'state': 'IL',
#     'zip_code': '60661'},
#    'name': "Old St. Patrick's Church",
#    'phone': '+13126481021',
#    'rating': 4.0,
#    'review_count': 46,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/old-st-patricks-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'urban-village-church-chicago-10',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.903251, 'longitude': -87.666789},
#    'display_phone': '(312) 268-5300',
#    'distance': 932.798574125097,
#    'id': 'b29og5sUElQnQhjQ6T-n4g',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nl_kW4-PqHlN7SJOrqvpuw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1543 W Division St',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1543 W Division St', 'Chicago, IL 60642'],
#     'state': 'IL',
#     'zip_code': '60642'},
#    'name': 'Urban Village Church',
#    'phone': '+13122685300',
#    'rating': 5.0,
#    'review_count': 17,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/urban-village-church-chicago-10?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'fourth-presbyterian-church-chicago-2',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.8985045, 'longitude': -87.6246634},
#    'display_phone': '(312) 787-4570',
#    'distance': 4407.59372968533,
#    'id': 'vf5TLHJD5NEPtX23z5Q-Ow',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2IC18PVkhARbR5uExouVow/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '126 E Chestnut St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['126 E Chestnut St', 'Chicago, IL 60611'],
#     'state': 'IL',
#     'zip_code': '60611'},
#    'name': 'Fourth Presbyterian Church',
#    'phone': '+13127874570',
#    'rating': 4.0,
#    'review_count': 37,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/fourth-presbyterian-church-chicago-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'park-community-church-chicago-2',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.900443, 'longitude': -87.6437729},
#    'display_phone': '(312) 361-0500',
#    'distance': 2846.0482338448724,
#    'id': 'oCUztJfJSmTLT_DgC6v2Pg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dAnFIsdlGZFqbS-eRuiufA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1001 N Crosby',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1001 N Crosby', 'Chicago, IL 60611'],
#     'state': 'IL',
#     'zip_code': '60611'},
#    'name': 'Park Community Church',
#    'phone': '+13123610500',
#    'rating': 4.5,
#    'review_count': 31,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/park-community-church-chicago-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'zen-buddhist-temple-chicago-2',
#    'categories': [{'alias': 'buddhist_temples', 'title': 'Buddhist Temples'}],
#    'coordinates': {'latitude': 41.9453887939453,
#     'longitude': -87.671745300293},
#    'display_phone': '(773) 528-8685',
#    'distance': 4497.955265423522,
#    'id': 'HU_rHmYUlDstP_4WVn6btw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qz9R3RxrpHlwvm5neLr9yA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1710 W Cornelia Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1710 W Cornelia Ave', 'Chicago, IL 60657'],
#     'state': 'IL',
#     'zip_code': '60657'},
#    'name': 'Zen Buddhist Temple',
#    'phone': '+17735288685',
#    'rating': 5.0,
#    'review_count': 15,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/zen-buddhist-temple-chicago-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'first-united-methodist-church-at-the-chicago-temple-chicago-2',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.883038, 'longitude': -87.630569},
#    'display_phone': '(312) 236-4548',
#    'distance': 4616.373576902591,
#    'id': 'r2ELnPQc_wbUxu2YcB6FHQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Vej3KkORw-P8k6YMjO42Mg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '77 W Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['77 W Washington St', 'Chicago, IL 60602'],
#     'state': 'IL',
#     'zip_code': '60602'},
#    'name': 'First United Methodist Church at the Chicago Temple',
#    'phone': '+13122364548',
#    'rating': 4.5,
#    'review_count': 17,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/first-united-methodist-church-at-the-chicago-temple-chicago-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'crossroads-christian-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.962225, 'longitude': -87.664051},
#    'display_phone': '(773) 772-0400',
#    'distance': 6446.019740751874,
#    'id': '_F_WZGYO_psno2b-o6cQzg',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aVxBzTtSx6IJDkk3MaePeg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '4420 N Beacon St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['4420 N Beacon St', 'Chicago, IL 60640'],
#     'state': 'IL',
#     'zip_code': '60640'},
#    'name': 'Crossroads Christian Church',
#    'phone': '+17737720400',
#    'rating': 5.0,
#    'review_count': 13,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/crossroads-christian-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-joseph-church-chicago-2',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9022676, 'longitude': -87.637193},
#    'display_phone': '(312) 787-7174',
#    'distance': 3392.6810809948356,
#    'id': '7Ni5sakdGvqzrKgJSQ14Gg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q0CLRIa1OwHGQ43sQLwK4Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1107 N Orleans St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1107 N Orleans St', 'Chicago, IL 60610'],
#     'state': 'IL',
#     'zip_code': '60610'},
#    'name': 'St Joseph Church',
#    'phone': '+13127877174',
#    'rating': 4.5,
#    'review_count': 16,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-joseph-church-chicago-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'episcopal-church-of-the-atonement-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9867706298828,
#     'longitude': -87.6563186645508},
#    'display_phone': '(773) 271-2727',
#    'distance': 9244.639933986657,
#    'id': 'O2Ms39RiIgTEPuGynNjdRA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QNNrXDJmxr48F0DKVawIMg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '5749 N Kenmore Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['5749 N Kenmore Ave', 'Chicago, IL 60660'],
#     'state': 'IL',
#     'zip_code': '60660'},
#    'name': 'Episcopal Church of the Atonement',
#    'phone': '+17732712727',
#    'rating': 5.0,
#    'review_count': 10,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/episcopal-church-of-the-atonement-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'saint-clement-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.928163, 'longitude': -87.645822},
#    'display_phone': '(773) 281-0371',
#    'distance': 3678.094658057009,
#    'id': 'c6ZuRGw6tOtVtFiXtYPqdA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fehLr2kztmPAGOSl_l9yQg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '642 W Deming Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['642 W Deming Pl', 'Chicago, IL 60614'],
#     'state': 'IL',
#     'zip_code': '60614'},
#    'name': 'Saint Clement Church',
#    'phone': '+17732810371',
#    'rating': 4.5,
#    'review_count': 18,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/saint-clement-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'city-church-chicago-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.8944914638996,
#     'longitude': -87.6487997174263},
#    'display_phone': '(312) 243-0930',
#    'distance': 2620.085474849573,
#    'id': '0vkdZjja7uRCNIdkpw6Ifg',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VW6jtejg-1zJ9Q9UpDyYVA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '777 N Green St',
#     'address2': None,
#     'address3': None,
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['777 N Green St', 'Chicago, IL 60642'],
#     'state': 'IL',
#     'zip_code': '60642'},
#    'name': 'City Church Chicago',
#    'phone': '+13122430930',
#    'rating': 4.0,
#    'review_count': 33,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/city-church-chicago-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'the-moody-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9123095, 'longitude': -87.6326747},
#    'display_phone': '(312) 327-8600',
#    'distance': 3815.0816781099843,
#    'id': 'rcCYhOAVyATNsRdvq4_HJA',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yUFwSG09hdz1d-VofMQcLw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1635 N LaSalle',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1635 N LaSalle', 'Chicago, IL 60614'],
#     'state': 'IL',
#     'zip_code': '60614'},
#    'name': 'The Moody Church',
#    'phone': '+13123278600',
#    'rating': 4.0,
#    'review_count': 22,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/the-moody-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'queen-of-all-saints-basilica-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9951956, 'longitude': -87.7440773},
#    'display_phone': '(773) 736-6060',
#    'distance': 11377.034795596715,
#    'id': 'Q-T4Qb2dRQ2iDbPSXcTcjg',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eTFhQ-PnDopwBCDmNyG_zA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '6280 N Sauganash Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['6280 N Sauganash Ave', 'Chicago, IL 60646'],
#     'state': 'IL',
#     'zip_code': '60646'},
#    'name': 'Queen Of All Saints Basilica',
#    'phone': '+17737366060',
#    'rating': 5.0,
#    'review_count': 10,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/queen-of-all-saints-basilica-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'second-presbyterian-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.8559, 'longitude': -87.62437},
#    'display_phone': '(312) 225-4951',
#    'distance': 7052.835110268789,
#    'id': 'ABOJD21285mVXo21mvmzww',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YAn6VGlsOUjdddC9iXvx9g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1936 S Michigan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1936 S Michigan Ave', 'Chicago, IL 60616'],
#     'state': 'IL',
#     'zip_code': '60616'},
#    'name': 'Second Presbyterian Church',
#    'phone': '+13122254951',
#    'rating': 4.5,
#    'review_count': 15,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/second-presbyterian-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-vincent-depaul-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9218329, 'longitude': -87.6539826},
#    'display_phone': '(773) 325-8610',
#    'distance': 2737.2451852840018,
#    'id': 'EfnArFcJHF6DBNhE4zKUSg',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vcx654aq19ACzT8Ny9L8Wg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1010 W Webster Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1010 W Webster Ave', 'Chicago, IL 60614'],
#     'state': 'IL',
#     'zip_code': '60614'},
#    'name': 'St Vincent DePaul Church',
#    'phone': '+17733258610',
#    'rating': 4.5,
#    'review_count': 12,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-vincent-depaul-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'urban-village-church-chicago-9',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9815029, 'longitude': -87.659547},
#    'display_phone': '(312) 268-5300',
#    'distance': 8621.699835596137,
#    'id': 'FHeih_qb1BEy394X8Ize5Q',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/l6P11Qmdwek3ISrM0LDLZw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '5451 N Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['5451 N Broadway', 'Chicago, IL 60640'],
#     'state': 'IL',
#     'zip_code': '60640'},
#    'name': 'Urban Village Church',
#    'phone': '+13122685300',
#    'rating': 4.5,
#    'review_count': 17,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/urban-village-church-chicago-9?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'people-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9026168, 'longitude': -87.6861295},
#    'display_phone': '',
#    'distance': 747.7457311733391,
#    'id': 'vKQg17zz7_dCccdhInhpGA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xK3OlZ6ZrKWX4SywiT631g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1147 N Western Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1147 N Western Ave', 'Chicago, IL 60622'],
#     'state': 'IL',
#     'zip_code': '60622'},
#    'name': 'People Church',
#    'phone': '',
#    'rating': 5.0,
#    'review_count': 8,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/people-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'our-lady-of-mount-carmel-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9401497, 'longitude': -87.6472421},
#    'display_phone': '(773) 525-0453',
#    'distance': 4648.476411271631,
#    'id': '1-iTfE0GG7p-PqrMIo3TcA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bYJCl8oXCmXfGqhrVjylJQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '708 W Belmont Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['708 W Belmont Ave', 'Chicago, IL 60657'],
#     'state': 'IL',
#     'zip_code': '60657'},
#    'name': 'Our Lady of Mount Carmel Church',
#    'phone': '+17735250453',
#    'rating': 4.0,
#    'review_count': 21,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/our-lady-of-mount-carmel-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-alphonsus-church-chicago-2',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.935859, 'longitude': -87.663963},
#    'display_phone': '(773) 525-0709',
#    'distance': 3599.5856795860473,
#    'id': 'p8wTos9diLPoNFCg9aQYrg',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aP-nQm27caw8WpRJJ3laWw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1429 W Wellington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1429 W Wellington Ave', 'Chicago, IL 60657'],
#     'state': 'IL',
#     'zip_code': '60657'},
#    'name': 'St Alphonsus Church',
#    'phone': '+17735250709',
#    'rating': 3.5,
#    'review_count': 36,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-alphonsus-church-chicago-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'urban-village-church-chicago-12',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.8740166, 'longitude': -87.624792},
#    'display_phone': '(312) 268-5300',
#    'distance': 5587.431489749772,
#    'id': 'jzlUF6U7viXcSVylmGP9FA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q2yBCkzvlek-SXfZMOfaUw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '610 S Michigan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['610 S Michigan Ave', 'Chicago, IL 60605'],
#     'state': 'IL',
#     'zip_code': '60605'},
#    'name': 'Urban Village Church',
#    'phone': '+13122685300',
#    'rating': 5.0,
#    'review_count': 8,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/urban-village-church-chicago-12?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'saint-adalberts-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.8588205, 'longitude': -87.6676814},
#    'display_phone': '(312) 226-0340',
#    'distance': 5207.881289163207,
#    'id': 'MeKyAb3lCU9go2_Jsw-9Bg',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/regRaF529OmAqZRgbI7MFw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1650 W 17th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1650 W 17th St', 'Chicago, IL 60608'],
#     'state': 'IL',
#     'zip_code': '60608'},
#    'name': "Saint Adalbert's Church",
#    'phone': '+13122260340',
#    'rating': 5.0,
#    'review_count': 9,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/saint-adalberts-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'holy-covenant-united-methodist-church-chicago-2',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9323997497559,
#     'longitude': -87.6524200439453},
#    'display_phone': '(773) 528-6462',
#    'distance': 3684.9589250866798,
#    'id': 'DG1d165FAh8lDuZ_zYHTuQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mMvLn1DuHSkl-zvrsapFHA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '925 W Diversey Pkwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['925 W Diversey Pkwy', 'Chicago, IL 60614'],
#     'state': 'IL',
#     'zip_code': '60614'},
#    'name': 'Holy Covenant United Methodist Church',
#    'phone': '+17735286462',
#    'rating': 5.0,
#    'review_count': 9,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/holy-covenant-united-methodist-church-chicago-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-james-cathedral-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.8947622, 'longitude': -87.6262349},
#    'display_phone': '(312) 787-7360',
#    'distance': 4464.358208231318,
#    'id': 'xEusRKBwhHctal57EVu0ZQ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mCSwcO-o2Mi69vM47EKBUA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '65 E Huron St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['65 E Huron St', 'Chicago, IL 60611'],
#     'state': 'IL',
#     'zip_code': '60611'},
#    'name': 'St James Cathedral',
#    'phone': '+13127877360',
#    'rating': 4.5,
#    'review_count': 13,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-james-cathedral-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-gertrudes-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9946211, 'longitude': -87.6659372},
#    'display_phone': '(773) 764-3621',
#    'distance': 10007.213797647662,
#    'id': 'fzJJ4ppO0FRg-4sTcxuZIA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3j5y1FiuqJ0LmD0sc0UnYQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1420 W Granville Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1420 W Granville Ave', 'Chicago, IL 60660'],
#     'state': 'IL',
#     'zip_code': '60660'},
#    'name': 'St Gertrudes Church',
#    'phone': '+17737643621',
#    'rating': 4.5,
#    'review_count': 12,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-gertrudes-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'church-of-our-saviour-episcopal-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9256349, 'longitude': -87.6425285},
#    'display_phone': '(773) 549-3832',
#    'distance': 3713.002749629111,
#    'id': 'Uac9G41gMoNzd2k4qCAguw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3__3YN-mhbKv42LqtD3z8w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '530 W Fullerton Pkwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['530 W Fullerton Pkwy', 'Chicago, IL 60614'],
#     'state': 'IL',
#     'zip_code': '60614'},
#    'name': 'Church of Our Saviour Episcopal',
#    'phone': '+17735493832',
#    'rating': 5.0,
#    'review_count': 9,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/church-of-our-saviour-episcopal-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'shambhala-meditation-center-of-chicago-chicago',
#    'categories': [{'alias': 'buddhist_temples', 'title': 'Buddhist Temples'},
#     {'alias': 'meditationcenters', 'title': 'Meditation Centers'},
#     {'alias': 'nonprofit', 'title': 'Community Service/Non-Profit'}],
#    'coordinates': {'latitude': 41.8821968883276,
#     'longitude': -87.6531435549259},
#    'display_phone': '(773) 743-8147',
#    'distance': 3225.1640984220876,
#    'id': 'arjjSF7aTtGRm-L_tiIwPg',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ynusgiuf-qvs4sCLA6H6sA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '37 N Carpenter St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['37 N Carpenter St', 'Chicago, IL 60607'],
#     'state': 'IL',
#     'zip_code': '60607'},
#    'name': 'Shambhala Meditation Center of Chicago',
#    'phone': '+17737438147',
#    'rating': 4.5,
#    'review_count': 10,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/shambhala-meditation-center-of-chicago-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-peters-church-chicago-3',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.8821049, 'longitude': -87.6311979},
#    'display_phone': '(312) 372-5111',
#    'distance': 4611.586775315821,
#    'id': 'WicUvrapdgrNjrk5724DtQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HIJzOOt_qg7jDT_BbRNDag/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '110 W Madison St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['110 W Madison St', 'Chicago, IL 60602'],
#     'state': 'IL',
#     'zip_code': '60602'},
#    'name': "St. Peter's Church",
#    'phone': '+13123725111',
#    'rating': 5.0,
#    'review_count': 7,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-peters-church-chicago-3?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'mishkan-chicago-chicago',
#    'categories': [{'alias': 'synagogues', 'title': 'Synagogues'}],
#    'coordinates': {'latitude': 41.954535, 'longitude': -87.673309},
#    'display_phone': '(773) 893-0613',
#    'distance': 5502.686305754684,
#    'id': 'DHb0feluv8sVFE0xrQ8K-w',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Id6uwAY5-q1P2nWHuzs2yQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '4001 N Ravenswood',
#     'address2': 'Ste 101',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['4001 N Ravenswood', 'Ste 101', 'Chicago, IL 60613'],
#     'state': 'IL',
#     'zip_code': '60613'},
#    'name': 'Mishkan Chicago',
#    'phone': '+17738930613',
#    'rating': 5.0,
#    'review_count': 11,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/mishkan-chicago-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'soul-city-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.8792757295675,
#     'longitude': -87.6567485579274},
#    'display_phone': '(312) 252-3062',
#    'distance': 3362.996075982817,
#    'id': 'tXkuacfu2G_4OPYddIvlmg',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qEoaNvaNyLIH6zhbROObpQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1130 W Adams St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1130 W Adams St', 'Chicago, IL 60607'],
#     'state': 'IL',
#     'zip_code': '60607'},
#    'name': 'Soul City Church',
#    'phone': '+13122523062',
#    'rating': 4.0,
#    'review_count': 17,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/soul-city-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'our-lady-of-sorrows-basilica-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.877159, 'longitude': -87.704005},
#    'display_phone': '(773) 638-5800',
#    'distance': 3796.244439500621,
#    'id': 'x9uEqzqo6sTAcwfKAxHmbA',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aw67OAQeCaFwoAwo8OsOXA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '3121 W Jackson Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['3121 W Jackson Blvd', 'Chicago, IL 60612'],
#     'state': 'IL',
#     'zip_code': '60612'},
#    'name': 'Our Lady of Sorrows Basilica',
#    'phone': '+17736385800',
#    'rating': 4.5,
#    'review_count': 9,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/our-lady-of-sorrows-basilica-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'armitage-baptist-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9263756, 'longitude': -87.706742},
#    'display_phone': '(773) 384-6800',
#    'distance': 3362.4560464561964,
#    'id': 'pJP3utMbuVpqAiZ3YXCWDA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/w7zB68MgLPTZKQ_AlK14JQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '2451 N Kedzie Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['2451 N Kedzie Blvd', 'Chicago, IL 60647'],
#     'state': 'IL',
#     'zip_code': '60647'},
#    'name': 'Armitage Baptist Church',
#    'phone': '+17733846800',
#    'rating': 5.0,
#    'review_count': 7,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/armitage-baptist-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'willow-creek-community-church-downtown-chicago-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.8651121, 'longitude': -87.6270097},
#    'display_phone': '(312) 436-9000',
#    'distance': 6122.373817105389,
#    'id': 'CFekf2jdl8NuVqPt6cLodQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6XXEWPAHZzQz1y2YDPsK5Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1319 S State St',
#     'address2': '',
#     'address3': 'The Auditorium Theatre',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1319 S State St',
#      'The Auditorium Theatre',
#      'Chicago, IL 60605'],
#     'state': 'IL',
#     'zip_code': '60605'},
#    'name': 'Willow Creek Community Church - Downtown Chicago',
#    'phone': '+13124369000',
#    'rating': 4.5,
#    'review_count': 10,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/willow-creek-community-church-downtown-chicago-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'metro-praise-international-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.93108, 'longitude': -87.761581},
#    'display_phone': '(773) 930-0956',
#    'distance': 7510.17429620968,
#    'id': 'gJnqY5o4KZLK5Yo0qQ7lkQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AzHHUCvGQ6yYQxkHkr2xEw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '5405 W Diversey Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['5405 W Diversey Ave', 'Chicago, IL 60639'],
#     'state': 'IL',
#     'zip_code': '60639'},
#    'name': 'Metro Praise International Church',
#    'phone': '+17739300956',
#    'rating': 5.0,
#    'review_count': 8,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/metro-praise-international-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'holy-family-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.867187332615, 'longitude': -87.654688295084},
#    'display_phone': '(312) 492-8442',
#    'distance': 4634.323789466989,
#    'id': 'ML9GSezIjP0U3wxHswCGww',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/t3B0xiW1AnDCXjQeEArt7Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1080 W Roosevelt Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1080 W Roosevelt Rd', 'Chicago, IL 60608'],
#     'state': 'IL',
#     'zip_code': '60608'},
#    'name': 'Holy Family Church',
#    'phone': '+13124928442',
#    'rating': 4.5,
#    'review_count': 12,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/holy-family-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'saint-hedwig-catholic-church-chicago-2',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9220237731934,
#     'longitude': -87.6808547973633},
#    'display_phone': '(773) 486-1660',
#    'distance': 1866.4026416832514,
#    'id': 'EgBC-09pS_QadbeedlCGEw',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XLtdwC6cmI-w1IxXs8qBjw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '2226 N Hoyne Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['2226 N Hoyne Ave', 'Chicago, IL 60647'],
#     'state': 'IL',
#     'zip_code': '60647'},
#    'name': 'Saint Hedwig Catholic Church',
#    'phone': '+17734861660',
#    'rating': 5.0,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/saint-hedwig-catholic-church-chicago-2?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'grace-united-methodist-church-of-logan-square-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9281925, 'longitude': -87.7112907},
#    'display_phone': '(773) 697-4442',
#    'distance': 3802.4154376870715,
#    'id': 'DxxnRFlEFkrYQoVSNT7JMQ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vq5RsJhdSr4bIgPsQ_fVDQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '3325 W Wrightwood Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['3325 W Wrightwood Ave', 'Chicago, IL 60647'],
#     'state': 'IL',
#     'zip_code': '60647'},
#    'name': 'Grace United Methodist Church of Logan Square',
#    'phone': '+17736974442',
#    'rating': 5.0,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/grace-united-methodist-church-of-logan-square-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'midwest-buddhist-temple-chicago',
#    'categories': [{'alias': 'buddhist_temples', 'title': 'Buddhist Temples'}],
#    'coordinates': {'latitude': 41.914574, 'longitude': -87.6399249},
#    'display_phone': '(312) 943-7801',
#    'distance': 3299.321366547044,
#    'id': '3x2k895AG7zpBdC0gPzuxg',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/i3KSqdhb0p5yaOGhMJoE6w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '435 W Menomonee St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['435 W Menomonee St', 'Chicago, IL 60614'],
#     'state': 'IL',
#     'zip_code': '60614'},
#    'name': 'Midwest Buddhist Temple',
#    'phone': '+13129437801',
#    'rating': 4.0,
#    'review_count': 11,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/midwest-buddhist-temple-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'unity-church-in-chicago-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9954746216536,
#     'longitude': -87.6775798201561},
#    'display_phone': '(773) 973-0007',
#    'distance': 10018.657273281473,
#    'id': 'JPXICBPsWqgbEzZintZ7yg',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PGKFaxih_wy5vP0gGYv6hA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1925 W Thome Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1925 W Thome Ave', 'Chicago, IL 60660'],
#     'state': 'IL',
#     'zip_code': '60660'},
#    'name': 'Unity Church In Chicago',
#    'phone': '+17739730007',
#    'rating': 5.0,
#    'review_count': 7,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/unity-church-in-chicago-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'tabor-lutheran-church-chicago-3',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9632, 'longitude': -87.71723},
#    'display_phone': '(773) 588-4040',
#    'distance': 7207.638065185325,
#    'id': 'wzsZL5lIG4ItRbbEVGNAow',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6rLG-VgrPQ05LGt-G_mDNw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '3542 W Sunnyside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['3542 W Sunnyside Ave', 'Chicago, IL 60625'],
#     'state': 'IL',
#     'zip_code': '60625'},
#    'name': 'Tabor Lutheran Church',
#    'phone': '+17735884040',
#    'rating': 5.0,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/tabor-lutheran-church-chicago-3?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'grace-chicago-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9413523375988,
#     'longitude': -87.6444900780916},
#    'display_phone': '(312) 927-1323',
#    'distance': 4889.818686064567,
#    'id': '62i0EIlt31vLI0gclJRq6Q',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/e81YQv9EElg92u7zboBtgw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': 'Nettelhorst School',
#     'address2': '',
#     'address3': '3252 N Broadway',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['Nettelhorst School',
#      '3252 N Broadway',
#      'Chicago, IL 60657'],
#     'state': 'IL',
#     'zip_code': '60657'},
#    'name': 'Grace Chicago Church',
#    'phone': '+13129271323',
#    'rating': 5.0,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/grace-chicago-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'all-saints-episcopal-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.96494, 'longitude': -87.6729299},
#    'display_phone': '(773) 561-0111',
#    'distance': 6663.344395896887,
#    'id': 'S2tyzn7s_I3vynFv5bvg1g',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KBdPrMRwfkZa-8XJUou6YQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '4550 N Hermitage Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['4550 N Hermitage Ave', 'Chicago, IL 60640'],
#     'state': 'IL',
#     'zip_code': '60640'},
#    'name': 'All Saints Episcopal Church',
#    'phone': '+17735610111',
#    'rating': 5.0,
#    'review_count': 7,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/all-saints-episcopal-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'emanuel-congregation-chicago',
#    'categories': [{'alias': 'synagogues', 'title': 'Synagogues'}],
#    'coordinates': {'latitude': 41.990517, 'longitude': -87.654799},
#    'display_phone': '(773) 561-5173',
#    'distance': 9679.508388767708,
#    'id': 'uOyQy30N1DjF2tGJsF6gMw',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QwwQS3dQzaRPZB6DmZMgfg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '5959 N Sheridan Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['5959 N Sheridan Rd', 'Chicago, IL 60660'],
#     'state': 'IL',
#     'zip_code': '60660'},
#    'name': 'Emanuel Congregation',
#    'phone': '+17735615173',
#    'rating': 4.5,
#    'review_count': 11,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/emanuel-congregation-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'st-james-chapel-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.8978503, 'longitude': -87.6259407},
#    'display_phone': '(312) 787-8625',
#    'distance': 4374.902400463557,
#    'id': 'TOBNbRIbzszr2RbUUdaf7w',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ArsuqjqqKdC3OQLHbzbwcA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '835 N Rush St',
#     'address2': '',
#     'address3': 'The Quigley Center of the Archdiocese of Chicago',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['835 N Rush St',
#      'The Quigley Center of the Archdiocese of Chicago',
#      'Chicago, IL 60611'],
#     'state': 'IL',
#     'zip_code': '60611'},
#    'name': 'St. James Chapel',
#    'phone': '+13127878625',
#    'rating': 5.0,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/st-james-chapel-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'downtown-islamic-center-chicago',
#    'categories': [{'alias': 'mosques', 'title': 'Mosques'}],
#    'coordinates': {'latitude': 41.878692, 'longitude': -87.627243},
#    'display_phone': '(312) 939-9095',
#    'distance': 5107.8636139963655,
#    'id': 'tOGPsjNHjI-R40pOUiNXxg',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rYvV01Hs5R1kWEX58rcQwA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '231 S State St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['231 S State St', 'Chicago, IL 60604'],
#     'state': 'IL',
#     'zip_code': '60604'},
#    'name': 'Downtown Islamic Center',
#    'phone': '+13129399095',
#    'rating': 4.0,
#    'review_count': 11,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/downtown-islamic-center-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'holy-trinity-lutheran-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.947365, 'longitude': -87.660136},
#    'display_phone': '(773) 248-1233',
#    'distance': 4914.450536169037,
#    'id': 'NM9ZZBXKg0N5zLzL89zyug',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SJw9-mBxlp9aIekDTgxvdg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1218 W Addison St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1218 W Addison St', 'Chicago, IL 60613'],
#     'state': 'IL',
#     'zip_code': '60613'},
#    'name': 'Holy Trinity Lutheran Church',
#    'phone': '+17732481233',
#    'rating': 5.0,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/holy-trinity-lutheran-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'immaculate-conception-church-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9079184, 'longitude': -87.6363879},
#    'display_phone': '(312) 787-7174',
#    'distance': 3471.5677906809574,
#    'id': 'mzF-p3lD5UKnhg4MBtHP9w',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2iY8sszYLQMIl-fLJ1pFCA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1431 N North Park Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['1431 N North Park Ave', 'Chicago, IL 60610'],
#     'state': 'IL',
#     'zip_code': '60610'},
#    'name': 'Immaculate Conception Church',
#    'phone': '+13127877174',
#    'rating': 4.5,
#    'review_count': 7,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/immaculate-conception-church-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'},
#   {'alias': 'best-church-of-god-chicago',
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'coordinates': {'latitude': 41.9265199, 'longitude': -87.64976},
#    'display_phone': '(773) 871-3000',
#    'distance': 3302.589498610975,
#    'id': 'nCPhzzK0FMk9jRUsna99dw',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '2433 N Lincoln Ave',
#     'address2': '',
#     'address3': 'Victory Gardens Theater',
#     'city': 'Chicago',
#     'country': 'US',
#     'display_address': ['2433 N Lincoln Ave',
#      'Victory Gardens Theater',
#      'Chicago, IL 60614'],
#     'state': 'IL',
#     'zip_code': '60614'},
#    'name': 'Best Church Of God',
#    'phone': '+17738713000',
#    'rating': 5.0,
#    'review_count': 5,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/best-church-of-god-chicago?adjust_creative=k8fGyKKTQcMsVGR762YhKw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=k8fGyKKTQcMsVGR762YhKw'}],
#  'region': {'center': {'latitude': 41.90515925618311,
#    'longitude': -87.67776489257812}},
#  'total': 402}

# %%
with open('ChicagoSearchData.json', 'w') as outfile:
    json.dump(biginfolist, outfile)
